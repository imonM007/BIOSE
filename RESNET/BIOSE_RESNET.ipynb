# %%
# Import required libraries
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import os
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# Set random seed for reproducibility
torch.manual_seed(42)
np.random.seed(42)

# Step 1: Set up device and parameters
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Configuration dictionary
config = {
    "folder1_path": r"C:\Users\Talha\Documents\BIOSE\Datasetimon\Dataset\Dataset\image",
    "folder2_path": r"C:\Users\Talha\Documents\BIOSE\Datasetimon\Dataset\Dataset\label",
    "batch_size": 32,
    "learning_rate": 0.001,
    "num_epochs": 20,
    "image_size": 224,
    "num_classes": 2,
    "val_split": 0.1111,  # Adjusted for 80/10/10 split (80/720 ≈ 0.1111)
    "test_split": 0.1     # 10% for test
}

## Step 2: Create dataset class
class PairedImageDataset(Dataset):
    def __init__(self, pairs, labels, transform=None):
        self.pairs = pairs
        self.labels = labels
        self.transform = transform
        
    def __len__(self):
        return len(self.pairs)
    
    def __getitem__(self, idx):
        img1_path, img2_path = self.pairs[idx]
        label = self.labels[idx]
        
        img1 = Image.open(img1_path).convert('RGB')
        img2 = Image.open(img2_path).convert('RGB')
        
        if self.transform:
            img1 = self.transform(img1)
            img2 = self.transform(img2)
            
        return img1, img2, torch.tensor(label, dtype=torch.long)

## Step 3: Prepare data loaders
def prepare_data_loaders(folder1, folder2, config):
    # Get all image files from both folders (support multiple extensions)
    extensions = ['*.jpg', '*.png', '*.jpeg']
    images1 = []
    images2 = []
    
    for ext in extensions:
        images1.extend(sorted(glob(os.path.join(folder1, ext))))
        images2.extend(sorted(glob(os.path.join(folder2, ext))))
    
    # Remove duplicates (in case some images match multiple extensions)
    images1 = sorted(list(set(images1)))
    images2 = sorted(list(set(images2)))
    
    # Debug: Print the number of images found
    print(f"Found {len(images1)} images in folder1: {folder1}")
    print(f"Found {len(images2)} images in folder2: {folder2}")
    
    # Verify we have matching pairs
    if len(images1) != len(images2):
        raise ValueError(f"Number of images in both folders must match. Found {len(images1)} in folder1 and {len(images2)} in folder2.")
    
    # Check if the dataset is empty
    if len(images1) == 0:
        raise ValueError("No images found in one or both folders. Check the folder paths and ensure they contain images.")
    
    # Create pairs (assuming corresponding images have same names or order)
    pairs = list(zip(images1, images2))
    
    # Create labels (modify this based on your labeling strategy)
    # This example assumes all pairs belong to class 0 - update as needed
    labels = np.zeros(len(pairs))  # Replace with your actual labels
    
    # Check if the dataset size matches expectation
    expected_size = 800
    if len(pairs) != expected_size:
        print(f"Warning: Expected {expected_size} pairs, but found {len(pairs)} pairs.")
    
    # Split data into train, validation, and test for 80/10/10 split
    # First split: 10% for test (80 pairs)
    train_val_pairs, test_pairs, train_val_labels, test_labels = train_test_split(
        pairs, labels, test_size=config["test_split"], random_state=42)
    
    # Second split: From the remaining 90% (720 pairs), take 80/720 ≈ 0.1111 for validation (80 pairs)
    train_pairs, val_pairs, train_labels, val_labels = train_test_split(
        train_val_pairs, train_val_labels, test_size=config["val_split"], random_state=42)
    
    # Debug: Print the sizes of each split
    print(f"Train set: {len(train_pairs)} pairs (expected: 640)")
    print(f"Validation set: {len(val_pairs)} pairs (expected: 80)")
    print(f"Test set: {len(test_pairs)} pairs (expected: 80)")
    
    # Define transformations
    train_transform = transforms.Compose([
        transforms.Resize((config["image_size"], config["image_size"])),
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.RandomRotation(15),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    val_transform = transforms.Compose([
        transforms.Resize((config["image_size"], config["image_size"])),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    # Create datasets
    train_dataset = PairedImageDataset(train_pairs, train_labels, train_transform)
    val_dataset = PairedImageDataset(val_pairs, val_labels, val_transform)
    test_dataset = PairedImageDataset(test_pairs, test_labels, val_transform)
    
    # Create data loaders
    train_loader = DataLoader(train_dataset, batch_size=config["batch_size"], shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=config["batch_size"], shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=config["batch_size"], shuffle=False)
    
    return train_loader, val_loader, test_loader

## Step 4: Define the ResNet model
class PairedResNet(nn.Module):
    def __init__(self, num_classes):
        super(PairedResNet, self).__init__()
        # Load pretrained ResNet
        self.resnet = models.resnet18(pretrained=True)
        
        # Remove the final fully connected layer
        self.feature_extractor = nn.Sequential(*list(self.resnet.children())[:-1])
        
        # Freeze early layers (optional)
        for param in self.feature_extractor[:5].parameters():
            param.requires_grad = False
        
        # New layers for processing pairs
        self.fc = nn.Sequential(
            nn.Linear(512 * 2, 512),  # 512 features from each image
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )
        
    def forward_one(self, x):
        x = self.feature_extractor(x)
        x = x.view(x.size(0), -1)
        return x
    
    def forward(self, x1, x2):
        # Process both images
        feat1 = self.forward_one(x1)
        feat2 = self.forward_one(x2)
        
        # Concatenate features
        combined = torch.cat((feat1, feat2), dim=1)
        
        # Final classification
        output = self.fc(combined)
        return output

## Step 5: Training and validation functions
def train_epoch(model, loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for img1, img2, labels in tqdm(loader, desc="Training"):
        img1 = img1.to(device)
        img2 = img2.to(device)
        labels = labels.to(device)
        
        optimizer.zero_grad()
        
        outputs = model(img1, img2)
        loss = criterion(outputs, labels)
        
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    epoch_loss = running_loss / len(loader)
    epoch_acc = correct / total
    return epoch_loss, epoch_acc

def validate(model, loader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    
    with torch.no_grad():
        for img1, img2, labels in tqdm(loader, desc="Validating"):
            img1 = img1.to(device)
            img2 = img2.to(device)
            labels = labels.to(device)
            
            outputs = model(img1, img2)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    val_loss = running_loss / len(loader)
    val_acc = correct / total
    return val_loss, val_acc

## Step 6: Main training loop
def main(config):
    # Prepare data loaders
    train_loader, val_loader, test_loader = prepare_data_loaders(
        config["folder1_path"], config["folder2_path"], config)
    
    # Initialize model
    model = PairedResNet(config["num_classes"]).to(device)
    
    # Loss function and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=config["learning_rate"])
    
    # Learning rate scheduler
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.1)
    
    # Training history
    history = {
        'train_loss': [],
        'train_acc': [],
        'val_loss': [],
        'val_acc': []
    }
    
    best_val_acc = 0.0
    
    # Training loop
    for epoch in range(config["num_epochs"]):
        print(f"\nEpoch {epoch + 1}/{config['num_epochs']}")
        
        # Train
        train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, device)
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        
        # Validate
        val_loss, val_acc = validate(model, val_loader, criterion, device)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)
        
        # Update scheduler
        scheduler.step(val_loss)
        
        print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f}")
        print(f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")
        
        # Save best model
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), 'best_model.pth')
            print("Saved new best model")
    
    # Plot training history
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(history['train_loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Val Loss')
    plt.title('Loss over epochs')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(history['train_acc'], label='Train Accuracy')
    plt.plot(history['val_acc'], label='Val Accuracy')
    plt.title('Accuracy over epochs')
    plt.legend()
    
    plt.tight_layout()
    plt.show()
    
    # Test the model
    print("\nTesting on test set...")
    test_loss, test_acc = validate(model, test_loader, criterion, device)
    print(f"Test Loss: {test_loss:.4f} | Test Acc: {test_acc:.4f}")
    
    return model, history

## Step 7: Run the training
# Update these paths with your actual folder paths
config["folder1_path"] = r"C:\Users\Talha\Documents\BIOSE\Datasetimon\Dataset\Dataset\image"
config["folder2_path"] = r"C:\Users\Talha\Documents\BIOSE\Datasetimon\Dataset\Dataset\label"

# Run the training
trained_model, training_history = main(config)

# Save the final model
torch.save(trained_model.state_dict(), 'final_model.pth')
# Out:
# Using device: cpu
# Found 1800 images in folder1: C:\Users\Talha\Documents\BIOSE\Datasetimon\Dataset\Dataset\image
# Found 1800 images in folder2: C:\Users\Talha\Documents\BIOSE\Datasetimon\Dataset\Dataset\label
# Warning: Expected 800 pairs, but found 1800 pairs.
# Train set: 1440 pairs (expected: 640)
# Validation set: 180 pairs (expected: 80)
# Test set: 180 pairs (expected: 80)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to C:\Users\Talha/.cache\torch\hub\checkpoints\resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:19<00:00, 2.39MB/s]
# Epoch 1/20
# Training: 100%|██████████| 45/45 [01:50<00:00,  2.45s/it]
# Validating: 100%|██████████| 6/6 [00:07<00:00,  1.22s/it]
# Train Loss: 0.0178 | Train Acc: 0.9854
# Val Loss: 0.0000 | Val Acc: 1.0000
# Saved new best model
#
# Epoch 2/20
# Training: 100%|██████████| 45/45 [01:39<00:00,  2.20s/it]
# Validating: 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# Train Loss: 0.0000 | Train Acc: 1.0000
# Val Loss: 0.0000 | Val Acc: 1.0000
#
# Epoch 3/20
# Training: 100%|██████████| 45/45 [01:38<00:00,  2.19s/it]
# Validating: 100%|██████████| 6/6 [00:05<00:00,  1.09it/s]
# Train Loss: 0.0000 | Train Acc: 1.0000
# Val Loss: 0.0000 | Val Acc: 1.0000
#
# Epoch 4/20
# Training: 100%|██████████| 45/45 [01:40<00:00,  2.23s/it]
# Validating: 100%|██████████| 6/6 [00:05<00:00,  1.03it/s]
# Train Loss: 0.0000 | Train Acc: 1.0000
# Val Loss: 0.0000 | Val Acc: 1.0000
#
# Epoch 5/20
# Training: 100%|██████████| 45/45 [01:38<00:00,  2.20s/it]
# Validating: 100%|██████████| 6/6 [00:05<00:00,  1.05it/s]
# Train Loss: 0.0000 | Train Acc: 1.0000
# Val Loss: 0.0000 | Val Acc: 1.0000
#
# Epoch 6/20
# Training: 100%|██████████| 45/45 [01:38<00:00,  2.19s/it]
# Validating: 100%|██████████| 6/6 [00:05<00:00,  1.03it/s]
# Train Loss: 0.0000 | Train Acc: 1.0000
# Val Loss: 0.0000 | Val Acc: 1.0000
#
# Epoch 7/20
# Training: 100%|██████████| 45/45 [01:43<00:00,  2.30s/it]
# Validating: 100%|██████████| 6/6 [00:06<00:00,  1.00s/it]
# Train Loss: 0.0000 | Train Acc: 1.0000
# Val Loss: 0.0000 | Val Acc: 1.0000
#
# Epoch 8/20
# Training: 100%|██████████| 45/45 [01:43<00:00,  2.29s/it]
# Validating: 100%|██████████| 6/6 [00:06<00:00,  1.06s/it]
# Train Loss: 0.0000 | Train Acc: 1.0000
# Val Loss: 0.0000 | Val Acc: 1.0000
#
# Epoch 9/20
# Training: 100%|██████████| 45/45 [01:43<00:00,  2.29s/it]
# Validating: 100%|██████████| 6/6 [00:06<00:00,  1.00s/it]
# Train Loss: 0.0000 | Train Acc: 1.0000
# Val Loss: 0.0000 | Val Acc: 1.0000
#
# Epoch 10/20
# Training: 100%|██████████| 45/45 [01:42<00:00,  2.27s/it]
# Validating: 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# Train Loss: 0.0000 | Train Acc: 1.0000
# Val Loss: 0.0000 | Val Acc: 1.0000
#
# Epoch 11/20
# Training: 100%|██████████| 45/45 [01:45<00:00,  2.35s/it]
# Validating: 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# Train Loss: 0.0000 | Train Acc: 1.0000
# Val Loss: 0.0000 | Val Acc: 1.0000
#
# Epoch 12/20
# Training: 100%|██████████| 45/45 [01:42<00:00,  2.28s/it]
# Validating: 100%|██████████| 6/6 [00:06<00:00,  1.00s/it]
# Train Loss: 0.0000 | Train Acc: 1.0000
# Val Loss: 0.0000 | Val Acc: 1.0000
#
# Epoch 13/20
# Training: 100%|██████████| 45/45 [01:40<00:00,  2.24s/it]
# Validating: 100%|██████████| 6/6 [00:05<00:00,  1.03it/s]
# Train Loss: 0.0000 | Train Acc: 1.0000
# Val Loss: 0.0000 | Val Acc: 1.0000
#
# Epoch 14/20
# Training: 100%|██████████| 45/45 [01:40<00:00,  2.24s/it]
# Validating: 100%|██████████| 6/6 [00:05<00:00,  1.05it/s]
# Train Loss: 0.0000 | Train Acc: 1.0000
# Val Loss: 0.0000 | Val Acc: 1.0000
#
# Epoch 15/20
# Training: 100%|██████████| 45/45 [01:39<00:00,  2.20s/it]
# Validating: 100%|██████████| 6/6 [00:05<00:00,  1.02it/s]
# Train Loss: 0.0000 | Train Acc: 1.0000
# Val Loss: 0.0000 | Val Acc: 1.0000
#
# Epoch 16/20
# Training: 100%|██████████| 45/45 [01:39<00:00,  2.20s/it]
# Validating: 100%|██████████| 6/6 [00:05<00:00,  1.01it/s]
# Train Loss: 0.0000 | Train Acc: 1.0000
# Val Loss: 0.0000 | Val Acc: 1.0000
#
# Epoch 17/20
# Training: 100%|██████████| 45/45 [01:39<00:00,  2.22s/it]
# Validating: 100%|██████████| 6/6 [00:05<00:00,  1.02it/s]
# Train Loss: 0.0000 | Train Acc: 1.0000
# Val Loss: 0.0000 | Val Acc: 1.0000
#
# Epoch 18/20
# Training: 100%|██████████| 45/45 [01:39<00:00,  2.20s/it]
# Validating: 100%|██████████| 6/6 [00:05<00:00,  1.03it/s]
# Train Loss: 0.0000 | Train Acc: 1.0000
# Val Loss: 0.0000 | Val Acc: 1.0000
#
# Epoch 19/20
# Training: 100%|██████████| 45/45 [01:41<00:00,  2.25s/it]
# Validating: 100%|██████████| 6/6 [00:05<00:00,  1.03it/s]
# Train Loss: 0.0000 | Train Acc: 1.0000
# Val Loss: 0.0000 | Val Acc: 1.0000
#
# Epoch 20/20
# Training: 100%|██████████| 45/45 [01:39<00:00,  2.21s/it]
# Validating: 100%|██████████| 6/6 [00:05<00:00,  1.03it/s]
# Train Loss: 0.0000 | Train Acc: 1.0000
# Val Loss: 0.0000 | Val Acc: 1.0000
# Testing on test set...
# Validating: 100%|██████████| 6/6 [00:07<00:00,  1.26s/it]
# Test Loss: 0.0000 | Test Acc: 1.0000

# %%
# Import required libraries
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import os
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# Set random seed for reproducibility
torch.manual_seed(42)
np.random.seed(42)

# Step 1: Set up device and parameters
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Configuration dictionary
config = {
    "folder1_path": r"C:\Users\Talha\Documents\BIOSE\Datasetimon\Dataset\Dataset\image",
    "folder2_path": r"C:\Users\Talha\Documents\BIOSE\Datasetimon\Dataset\Dataset\label",
    "batch_size": 32,
    "learning_rate": 0.0001,
    "num_epochs": 20,
    "image_size": 224,
    "num_classes": 2,
    "val_split": 0.1111,
    "test_split": 0.1,
    "patience": 5
}

## Step 2: Create dataset class
class PairedImageDataset(Dataset):
    def __init__(self, pairs, labels, transform=None):
        self.pairs = pairs
        self.labels = labels
        self.transform = transform
        
    def __len__(self):
        return len(self.pairs)
    
    def __getitem__(self, idx):
        img1_path, img2_path = self.pairs[idx]
        label = self.labels[idx]
        
        img1 = Image.open(img1_path).convert('RGB')
        img2 = Image.open(img2_path).convert('RGB')
        
        if self.transform:
            img1 = self.transform(img1)
            img2 = self.transform(img2)
            
        return img1, img2, torch.tensor(label, dtype=torch.long)

## Step 3: Prepare data loaders
def prepare_data_loaders(folder1, folder2, config):
    # Get all image files from both folders (support multiple extensions)
    extensions = ['*.jpg', '*.png', '*.jpeg']
    images1 = []
    images2 = []
    
    for ext in extensions:
        images1.extend(sorted(glob(os.path.join(folder1, ext))))
        images2.extend(sorted(glob(os.path.join(folder2, ext))))
    
    # Remove duplicates (in case some images match multiple extensions)
    images1 = sorted(list(set(images1)))
    images2 = sorted(list(set(images2)))
    
    # Debug: Print the number of images found
    print(f"Found {len(images1)} images in folder1: {folder1}")
    print(f"Found {len(images2)} images in folder2: {folder2}")
    
    # Verify we have matching pairs
    if len(images1) != len(images2):
        raise ValueError(f"Number of images in both folders must match. Found {len(images1)} in folder1 and {len(images2)} in folder2.")
    
    # Check if the dataset is empty
    if len(images1) == 0:
        raise ValueError("No images found in one or both folders. Check the folder paths and ensure they contain images.")
    
    # Create pairs (assuming corresponding images have same names or order)
    pairs = list(zip(images1, images2))
    
    # Assign labels based on a criterion (adjust based on your dataset)
    labels = []
    for img1_path, img2_path in pairs:
        filename = os.path.basename(img2_path).lower()
        # Adjust this criterion based on your dataset
        if "positive" in filename:  # Example: Use "positive" for class 1, "negative" for class 0
            labels.append(1)
        elif "negative" in filename:
            labels.append(0)
        else:
            # If the filename doesn't match the expected pattern, raise an error
            raise ValueError(f"Cannot determine label for {img2_path}. Expected 'positive' or 'negative' in filename.")
    labels = np.array(labels)
    
    # Check label distribution and ensure both classes are present
    label_counts = np.bincount(labels)
    if len(label_counts) < 2:
        raise ValueError(f"Dataset contains only one class (label distribution: {label_counts}). Binary classification requires both classes (0 and 1).")
    print(f"Label distribution: {label_counts} (0: {label_counts[0]}, 1: {label_counts[1]})")
    
    # Check if the dataset size matches expectation
    expected_size = 800
    if len(pairs) != expected_size:
        print(f"Warning: Expected {expected_size} pairs, but found {len(pairs)} pairs.")
    
    # Split data into train, validation, and test for 80/10/10 split
    train_val_pairs, test_pairs, train_val_labels, test_labels = train_test_split(
        pairs, labels, test_size=config["test_split"], random_state=42)
    
    train_pairs, val_pairs, train_labels, val_labels = train_test_split(
        train_val_pairs, train_val_labels, test_size=config["val_split"], random_state=42)
    
    # Debug: Print the sizes of each split
    print(f"Train set: {len(train_pairs)} pairs (expected: 640)")
    print(f"Validation set: {len(val_pairs)} pairs (expected: 80)")
    print(f"Test set: {len(test_pairs)} pairs (expected: 80)")
    
    # Define transformations with increased augmentation
    train_transform = transforms.Compose([
        transforms.Resize((config["image_size"], config["image_size"])),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomVerticalFlip(p=0.5),
        transforms.RandomRotation(30),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
        transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    val_transform = transforms.Compose([
        transforms.Resize((config["image_size"], config["image_size"])),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    # Create datasets
    train_dataset = PairedImageDataset(train_pairs, train_labels, train_transform)
    val_dataset = PairedImageDataset(val_pairs, val_labels, val_transform)
    test_dataset = PairedImageDataset(test_pairs, test_labels, val_transform)
    
    # Create data loaders
    train_loader = DataLoader(train_dataset, batch_size=config["batch_size"], shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=config["batch_size"], shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=config["batch_size"], shuffle=False)
    
    return train_loader, val_loader, test_loader

## Step 4: Define the ResNet model
class PairedResNet(nn.Module):
    def __init__(self, num_classes):
        super(PairedResNet, self).__init__()
        # Load pretrained ResNet
        self.resnet = models.resnet18(pretrained=True)
        
        # Remove the final fully connected layer
        self.feature_extractor = nn.Sequential(*list(self.resnet.children())[:-1])
        
        # Freeze fewer layers (unfreeze more for fine-tuning)
        for param in self.feature_extractor[:3].parameters():
            param.requires_grad = False
        
        # New layers for processing pairs
        self.fc = nn.Sequential(
            nn.Linear(512 * 2, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )
        
    def forward_one(self, x):
        x = self.feature_extractor(x)
        x = x.view(x.size(0), -1)
        return x
    
    def forward(self, x1, x2):
        # Process both images
        feat1 = self.forward_one(x1)
        feat2 = self.forward_one(x2)
        
        # Concatenate features
        combined = torch.cat((feat1, feat2), dim=1)
        
        # Final classification
        output = self.fc(combined)
        return output

## Step 5: Training and validation functions
def train_epoch(model, loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for img1, img2, labels in tqdm(loader, desc="Training"):
        img1 = img1.to(device)
        img2 = img2.to(device)
        labels = labels.to(device)
        
        optimizer.zero_grad()
        
        outputs = model(img1, img2)
        loss = criterion(outputs, labels)
        
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    epoch_loss = running_loss / len(loader)
    epoch_acc = correct / total
    return epoch_loss, epoch_acc

def validate(model, loader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    
    with torch.no_grad():
        for img1, img2, labels in tqdm(loader, desc="Validating"):
            img1 = img1.to(device)
            img2 = img2.to(device)
            labels = labels.to(device)
            
            outputs = model(img1, img2)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    val_loss = running_loss / len(loader)
    val_acc = correct / total
    return val_loss, val_acc

## Step 6: Main training loop with early stopping
def main(config):
    # Prepare data loaders
    train_loader, val_loader, test_loader = prepare_data_loaders(
        config["folder1_path"], config["folder2_path"], config)
    
    # Initialize model
    model = PairedResNet(config["num_classes"]).to(device)
    
    # Loss function and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=config["learning_rate"])
    
    # Learning rate scheduler
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.1)
    
    # Training history
    history = {
        'train_loss': [],
        'train_acc': [],
        'val_loss': [],
        'val_acc': []
    }
    
    best_val_acc = 0.0
    best_val_loss = float('inf')
    epochs_no_improve = 0
    early_stop = False
    
    # Training loop with early stopping
    for epoch in range(config["num_epochs"]):
        print(f"\nEpoch {epoch + 1}/{config['num_epochs']}")
        
        # Train
        train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, device)
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        
        # Validate
        val_loss, val_acc = validate(model, val_loader, criterion, device)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)
        
        # Update scheduler
        scheduler.step(val_loss)
        
        print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f}")
        print(f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")
        
        # Save best model based on validation accuracy
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), 'best_model.pth')
            print("Saved new best model based on validation accuracy")
        
        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= config["patience"]:
                print(f"Early stopping triggered after {epoch + 1} epochs")
                early_stop = True
                break
    
    # Plot training history
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(history['train_loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Val Loss')
    plt.title('Loss over epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(history['train_acc'], label='Train Accuracy')
    plt.plot(history['val_acc'], label='Val Accuracy')
    plt.title('Accuracy over epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout()
    plt.show()
    
    # Test the model
    print("\nTesting on test set...")
    test_loss, test_acc = validate(model, test_loader, criterion, device)
    print(f"Test Loss: {test_loss:.4f} | Test Acc: {test_acc:.4f}")
    
    return model, history

## Step 7: Run the training
# Update these paths with your actual folder paths
config["folder1_path"] = r"C:\Users\Talha\Documents\BIOSE\Datasetimon\Dataset\Dataset\image"
config["folder2_path"] = r"C:\Users\Talha\Documents\BIOSE\Datasetimon\Dataset\Dataset\label"

# Run the training
trained_model, training_history = main(config)

# Save the final model
torch.save(trained_model.state_dict(), 'final_model.pth')
# Out:
# Using device: cpu
# Found 1800 images in folder1: C:\Users\Talha\Documents\BIOSE\Datasetimon\Dataset\Dataset\image
# Found 1800 images in folder2: C:\Users\Talha\Documents\BIOSE\Datasetimon\Dataset\Dataset\label
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 350
#     347 config["folder2_path"] = r"C:\Users\Talha\Documents\BIOSE\Datasetimon\Dataset\Dataset\label"
#     349 # Run the training
# --> 350 trained_model, training_history = main(config)
#     352 # Save the final model
#     353 torch.save(trained_model.state_dict(), 'final_model.pth')
#
# Cell In[6], line 252, in main(config)
#     250 def main(config):
#     251     # Prepare data loaders
# --> 252     train_loader, val_loader, test_loader = prepare_data_loaders(
#     253         config["folder1_path"], config["folder2_path"], config)
#     255     # Initialize model
#     256     model = PairedResNet(config["num_classes"]).to(device)
#
# Cell In[6], line 101, in prepare_data_loaders(folder1, folder2, config)
#      98         labels.append(0)
#      99     else:
#     100         # If the filename doesn't match the expected pattern, raise an error
# --> 101         raise ValueError(f"Cannot determine label for {img2_path}. Expected 'positive' or 'negative' in filename.")
#     102 labels = np.array(labels)
#     104 # Check label distribution and ensure both classes are present
#
# ValueError: Cannot determine label for C:\Users\Talha\Documents\BIOSE\Datasetimon\Dataset\Dataset\label\cju0qkwl35piu0993l0dewei2.png. Expected 'positive' or 'negative' in filename.
